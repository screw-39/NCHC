# %%
import pandas as pd

log = pd.read_parquet('./T4_log.parquet')
log
# Out:
#           Account AllocCPUS AllocNodes  \
# 0            root         2          1
# 1            root         2          1
# 2            root         2          1
# 3            root         7          0
# 4            root         7          0
# ...           ...       ...        ...
# 206635  mst110307      1344         12
# 206636  mst110307       112          1
# 206637  mst110307      1344         12
# 206638  mst110307      1344         12
# 206639  gov113006       448          0
#
#                                          AllocTRES AssocID CPUTimeRAW  \
# 0               billing=2,cpu=2,mem=515350M,node=1       6          0
# 1               billing=2,cpu=2,mem=515350M,node=1       6          0
# 2                         cpu=2,mem=515350M,node=1       6          0
# 3                                                        6          0
# 4                                                        6          0
# ...

# %%
test = log.loc[0, 'End']
test
# Out:
# '2024-01-03T11:44:47'

# %%
import time
import datetime
#1704253487
#trans_test = int( time.mktime( datetime.datetime.strptime(test, "%Y-%m-%dT%H:%M:%S").timetuple() ) )
trans_test = int(datetime.datetime.strptime(test, "%Y-%m-%dT%H:%M:%S").timestamp())
#trans_test = datetime.datetime.fromtimestamp(test, tz=datetime.timezone.utc).strftime('%Y-%m-%d %H:%M:%S')
trans_test
# Out:
# 1704253487

# %%
#print(log.groupby('Account'))
log.columns
# Out:
# Index(['Account', 'AllocCPUS', 'AllocNodes', 'AllocTRES', 'AssocID',
#        'CPUTimeRAW', 'ElapsedRaw', 'Eligible', 'End', 'ExitCode', 'Flags',
#        'GID', 'Group', 'JobID', 'JobIDRaw', 'JobName', 'Layout', 'MaxDiskRead',
#        'MaxDiskWrite', 'MaxPages', 'MaxRSS', 'MaxVMSize', 'NCPUS', 'NNodes',
#        'NodeList', 'NTasks', 'Priority', 'Partition', 'QOS', 'QOSRAW',
#        'Reason', 'ReqCPUS', 'ReqMem', 'ReqNodes', 'ReqTRES', 'Reservation',
#        'ReservationId', 'Reserved', 'ResvCPU', 'ResvCPURAW', 'Start', 'State',
#        'Submit', 'Suspended', 'SystemCPU', 'SystemComment', 'TimelimitRaw',
#        'TotalCPU', 'UID', 'User', 'UserCPU', 'WorkDir'],
#       dtype='object')
